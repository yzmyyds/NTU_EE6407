# %%
#generate two 3 cluster datasets and plot them
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# Generate first dataset
X1, y1 = make_blobs(n_samples=300, centers=3, cluster_std=0.60, random_state=0)
# Generate second dataset
plt.plot(X1[:, 0], X1[:, 1], 'o', markerfacecolor='gray', markeredgecolor='k', markersize=6, alpha=0.5)
plt.show()

# %%
#centroid clustering
class Kmeans_Clustering:
